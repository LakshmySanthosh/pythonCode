# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
series = pd.read_csv('daily_temperature_timeseries.csv',header=0,index_col=0,parse_dates=True)
series.shape
# Out:
# (3650, 1)

# %%
series=series.iloc[:500]
series.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
series.plot()
plt.show()
